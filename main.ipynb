# %%
pip install pyvis beautifulsoup4
# Out:
# Requirement already satisfied: pyvis in ./venv/lib/python3.13/site-packages (0.3.2)
# Requirement already satisfied: beautifulsoup4 in ./venv/lib/python3.13/site-packages (4.13.3)
# Requirement already satisfied: ipython>=5.3.0 in ./venv/lib/python3.13/site-packages (from pyvis) (8.32.0)
# Requirement already satisfied: jinja2>=2.9.6 in ./venv/lib/python3.13/site-packages (from pyvis) (3.1.5)
# Requirement already satisfied: jsonpickle>=1.4.1 in ./venv/lib/python3.13/site-packages (from pyvis) (4.0.2)
# Requirement already satisfied: networkx>=1.11 in ./venv/lib/python3.13/site-packages (from pyvis) (3.4.2)
# Requirement already satisfied: soupsieve>1.2 in ./venv/lib/python3.13/site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./venv/lib/python3.13/site-packages (from beautifulsoup4) (4.12.2)
# Requirement already satisfied: decorator in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (2.19.1)
# Requirement already satisfied: stack_data in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./venv/lib/python3.13/site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.13/site-packages (from jinja2>=2.9.6->pyvis) (3.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./venv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (3.0.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.13/site-packages (from stack_data->ipython>=5.3.0->pyvis) (0.2.3)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# image caching

import requests
import os
from pathlib import Path
from urllib.parse import urlparse
from urllib.parse import parse_qs

def extract_card_image_name_from_url(image_url):
    parsed_url = urlparse(image_url)
    exact_card_name = parse_qs(parsed_url.query)['exact'][0]
    img_filename = exact_card_name.replace(' ', '') + '.png'
    return img_filename

def get_full_path_for_card_image(img_filename):
    cwd = os.getcwd() + '/card_img_cache/'
    Path(cwd).mkdir(parents=True, exist_ok=True)
    img_full_path = cwd + img_filename
    return img_full_path

def cache_card_image(image_url):
    img_filename = extract_card_image_name_from_url(image_url)
    img_full_path = get_full_path_for_card_image(img_filename)

    img_file = Path(img_full_path)
    if img_file.is_file():
        print(img_filename, "already downloaded")
    else:
        print('Downloading' ,exact_card_name, "to", img_full_path)
        img_data = requests.get(image_url).content
        with open(img_full_path, 'wb') as handler:
            handler.write(img_data)
    return img_full_path

# %%
# crawling
import requests
from bs4 import BeautifulSoup
import urllib.parse


def flatten(xss):
    return [x for xs in xss for x in xs]

def crawl_everything_for_a_card_name(card_name, color_name):
    card_name_url = urllib.parse.quote_plus(card_name)
    url ='https://commanderspellbook.com/search/?q='+card_name_url+'+ci%3A'+color_name+'+legal%3Acommander'
    #print(url)
    combos = crawl_until_the_end(url)
    return combos

def crawl_until_the_end(url):
    current_page = 1
    combos = []
    combos_found = True

    while combos_found:
        url_next = url + '&page=' + str(current_page )
        response = requests.get(url_next)

        soup = BeautifulSoup(response.content, 'html.parser')
        s = soup.find_all('h3', class_="heading-title", string='No Combos Found')
        if s:
            combos_found=False
        combos.append(crawl(response))
        current_page += 1
    return flatten(combos)

def crawl(response):
    if response.status_code == 200:
        combos = []
        soup = BeautifulSoup(response.content, 'html.parser')
        combo_results = soup.find_all('a', class_='comboResults_comboResult__VcfMx')
        for combo in combo_results:
            cards_html = combo.find_all('div', class_="card-name")
            images_html = combo.find_all('div', class_='cardTooltip_cardTooltip__3eItj')
            results_html = combo.find_all('div', class_="result")

            cards = []
            images = []
            results = []

            for i, card in enumerate(cards_html):
                cards.append(card.text.strip())
            for i, image in enumerate(images_html):
                src = image.find('img')['src']
                images.append(src)
            for i, result in enumerate(results_html):
                results.append(result.text.strip())

            combo = {
                "cards": cards,
                "images": images,
                "results": results
            }
            print(combo)

            combos.append(combo)
        return combos
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")

def digging_deeper(card_name, color_name):
    combos = crawl_everything_for_a_card_name(card_name, color_name)

    combo_pieces = []
    for combo in combos:
        cards = combo.get("cards")
        combo_pieces.append(cards)
    combo_pieces = set(flatten(combo_pieces))
    combo_pieces.remove(card_name)
    print(combo_pieces)

    combos_plus_one = []
    combos_plus_one.append(combos)
    for combo_piece in combo_pieces:
        c = crawl_everything_for_a_card_name(combo_piece, color_name)
        combos_plus_one.append(c)

    combos_plus_one = flatten(combos_plus_one)
    print(combos_plus_one)
    return combos_plus_one

# %%
# visualization

from cProfile import label
from pyvis.network import Network
import random

def add_all_edges(net, cards, results):
    r = lambda :random.randint(0, 255)
    color  ='#%02X%02X%02X' % (r(), r(), r())
    for card in cards:
        for other_card in cards:
            if card == other_card:
                continue
            net.add_edge(card, other_card, color=color, title='\n'.join(results))

def create_graph(combos):
    net = Network(height="1000px", width="100%", bgcolor="#222222", font_color="white", notebook=True, select_menu=True,
                  filter_menu=True)
    net.barnes_hut()
    if not combos:
        return
    for combo in combos:
        cards = combo.get("cards")
        images = combo.get("images")
        for i, card in enumerate(cards):
            img_full_path = cache_card_image(images[i])
            net.add_node(card, title=card, shape="image", image=img_full_path, size=20, mass=1)
        add_all_edges(net, cards, combo.get("results"))

    # set the size in relation to the number of connections
    for node in net.get_nodes():
        neighbors = net.neighbors(node)
        node_id = net.get_node(node)
        node_id['size'] = min(210, 20 + 10 * len(neighbors))
        node_id['mass'] = min(100, 1 + len(neighbors))

    net.show_buttons(filter_="physics")
    net.toggle_physics(True)
    net.show("cards.html")

cards_mock = ['Xyris, the Writhing Storm', 'Intruder Alarm', 'Lore Broker']
images_mock = ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Xyris%2C%20the%20Writhing%20Storm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Intruder%20Alarm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lore%20Broker&face=front']
results_mock = ['Infinite draw triggers for all players', 'Infinite looting for all players',
                    'Infinite self-discard triggers for all players', 'Near-infinite creature tokens',
                    'Near-infinite ETB', 'Near-infinite untap of all creatures']

t = {
    "cards": cards_mock,
    "images": images_mock,
    "results": results_mock
}

create_graph([t])
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Xyris,theWrithingStorm.png
# IntruderAlarm.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/LoreBroker.png
# cards.html

# %%
combos_plus_one = []

# %% [markdown]
# # HowTo use this?
# - add your colour identity
# - and the cards you want to start crawling the spellbook with below

# %%
color_name = "Azorius"
card_names = [
    "Abdel Adrian, Gorion's Ward",
    "Fiend Hunter",
    "Deadeye Navigator",
    "Phantom Steed",
    "Lumbering Battlement",
    "Suspension Field",
    "Glorious Protector",
    "Icewind Stalwart",
    "Wormfang Drake",
    "Teleportation Circle"
            ]

# %% [markdown]
# - `crawl_everything_for_a_card_name` looks for every combo in your colour identity that a given card is a part of
# - `digging_deeper` runs `crawl_everything_for_a_card_name`, but then also looks for every combo with your newly found combo piece

# %%
for card_name in card_names:
    print(card_name)
    
    combos = crawl_everything_for_a_card_name(card_name, color_name)
    #combos = digging_deeper(card_name, color_name)

    combos_plus_one.append(combos)
# Out:
# Abdel Adrian, Gorion's Ward
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Restoration Angel', 'Ephemerate'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Restoration%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ephemerate&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Felidar Guardian', 'Ephemerate'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Felidar%20Guardian&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ephemerate&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Restoration Angel', 'Cloudshift'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Restoration%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Felidar Guardian', 'Cloudshift'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Felidar%20Guardian&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Restoration Angel', 'Fiend Hunter'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Restoration%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front'], 'results': ['Infinite LTB', 'Infinite ETB', 'Infinite creature tokens', 'Infinite blinking of nonland permanents you control']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Archaeomancer', 'Ephemerate'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ephemerate&face=front'], 'results': ['Infinite LTB', 'Infinite ETB', 'Infinite storm count', 'Infinite creature tokens', 'Infinite blinking of nonland permanents you control', 'Infinite magecraft triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Eldrazi Displacer'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Eldrazi%20Displacer&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite mana nonland permanents you control can produce']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Cloudshift', 'Arcane Signet', 'Archaeomancer'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Arcane%20Signet&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite magecraft triggers', 'Infinite storm count', 'Infinite blinking of nonland permanents you control']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Restoration Angel', 'Essence Flux'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Restoration%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Essence Flux', 'Arcane Signet', 'Archaeomancer'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Arcane%20Signet&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite magecraft triggers', 'Infinite storm count', 'Infinite blinking of nonland permanents you control']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Felidar Guardian', 'Essence Flux'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Felidar%20Guardian&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Deadeye Navigator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Deadeye%20Navigator&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite mana nonland permanents you control can produce']}
# {'cards': ['Preston, the Vanisher', "Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Ephemerate'], 'images': ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Preston%2C%20the%20Vanisher&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ephemerate&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ['Preston, the Vanisher', "Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Cloudshift'], 'images': ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Preston%2C%20the%20Vanisher&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Touch the Spirit Realm', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Touch%20the%20Spirit%20Realm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Touch the Spirit Realm'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Touch%20the%20Spirit%20Realm&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Restoration Angel', 'Pegasus Guardian // Rescue the Foal'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Restoration%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Pegasus%20Guardian&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Journey to Nowhere', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', "Ashnod's Altar"], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Karmic%20Guide&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ashnod's%20Altar&face=front"], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite colorless mana', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Felidar Guardian', 'Pegasus Guardian // Rescue the Foal'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Felidar%20Guardian&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Pegasus%20Guardian&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Touch the Spirit Realm', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Touch%20the%20Spirit%20Realm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wispweaver Angel', 'Cloudshift'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wispweaver%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Phyrexian Altar'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Karmic%20Guide&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phyrexian%20Altar&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite colored mana', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wispweaver Angel', 'Ephemerate'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wispweaver%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ephemerate&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Cloudshift', "Commander's Sphere", 'Archaeomancer'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudshift&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Commander's%20Sphere&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite magecraft triggers', 'Infinite storm count', 'Infinite blinking of nonland permanents you control']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Oblivion Ring', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Journey to Nowhere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Touch the Spirit Realm'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Touch%20the%20Spirit%20Realm&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Journey to Nowhere', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Blasting Station'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Karmic%20Guide&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Blasting%20Station&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite damage', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Essence Flux', "Commander's Sphere", 'Archaeomancer'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Commander's%20Sphere&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB', 'Infinite magecraft triggers', 'Infinite storm count', 'Infinite blinking of nonland permanents you control']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Preston, the Vanisher', 'Fiend Hunter', 'Essence Flux'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Preston%2C%20the%20Vanisher&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wispweaver Angel', 'Pegasus Guardian // Rescue the Foal'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wispweaver%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Pegasus%20Guardian&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Glorious Protector'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', "Ashnod's Altar"], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Nim%20Deathmantle&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Ashnod's%20Altar&face=front"], 'results': ['Infinite blinking', 'Infinite colorless mana', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Archaeomancer', 'Splash Portal'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Archaeomancer&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Splash%20Portal&face=front'], 'results': ['Infinite LTB', 'Infinite ETB', 'Infinite storm count', 'Infinite creature tokens', 'Infinite blinking of nonland permanents you control', 'Infinite magecraft triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Detention Sphere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Detention%20Sphere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Suspension Field', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ['Preston, the Vanisher', "Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Pegasus Guardian // Rescue the Foal'], 'images': ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Preston%2C%20the%20Vanisher&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Pegasus%20Guardian&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Parallax Wave', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Parallax%20Wave&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Journey to Nowhere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Suspension Field', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Spark Double'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Suspension Field'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Mysterious Limousine'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mysterious%20Limousine&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Parallax Wave', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Parallax%20Wave&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Lumbering Battlement'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Wormfang Drake'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glorious%20Protector&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Touch the Spirit Realm'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Touch%20the%20Spirit%20Realm&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', 'Phyrexian Altar'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Nim%20Deathmantle&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phyrexian%20Altar&face=front'], 'results': ['Infinite blinking', 'Infinite colored mana', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Spark Double'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wispweaver Angel', 'Essence Flux'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wispweaver%20Angel&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Essence%20Flux&face=front'], 'results': ['Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Wormfang Drake'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Mysterious Limousine', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mysterious%20Limousine&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Mysterious Limousine'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mysterious%20Limousine&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Wormfang Drake'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Spark Double'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Journey to Nowhere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Suspension Field'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Fiend Hunter', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Detention Sphere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Detention%20Sphere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Detention Sphere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Detention%20Sphere&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Mysterious Limousine', 'Leonin Relic-Warder'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mysterious%20Limousine&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Leonin%20Relic-Warder&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Cloudstone Curio', 'Phyrexian Altar'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Cloudstone%20Curio&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phyrexian%20Altar&face=front'], 'results': ['Infinite blinking', 'Infinite colored mana', 'Infinite creature tokens', 'Infinite death triggers', 'Infinite ETB', 'Infinite LTB', 'Infinite sacrifice triggers', 'Infinite storm count']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ['Sakashima of a Thousand Faces', "Abdel Adrian, Gorion's Ward", 'Fiend Hunter'], 'images': ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Fiend%20Hunter&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Spark Double'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wormfang Drake', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Journey to Nowhere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wormfang Drake', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Suspension Field'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wormfang Drake', 'Glasspool Mimic // Glasspool Shore'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Glasspool%20Mimic&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wormfang Drake', 'Spark Double'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Mysterious Limousine'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mysterious%20Limousine&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Lumbering Battlement'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lumbering%20Battlement&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Wormfang Drake', 'Clever Impersonator'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clever%20Impersonator&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Oblivion Ring'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Oblivion%20Ring&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Phantom Steed'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Phantom%20Steed&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Journey to Nowhere'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Journey%20to%20Nowhere&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ['Sakashima of a Thousand Faces', "Abdel Adrian, Gorion's Ward", 'Wormfang Drake'], 'images': ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', "https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Wormfang%20Drake&face=front'], 'results': ['Infinite blinking of nonland permanents you control', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Clone'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Clone&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Suspension Field'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Mirror Image'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Mirror%20Image&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Suspension Field'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Suspension%20Field&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Spark Double', 'Icy Prison'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Spark%20Double&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Icy%20Prison&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}
# {'cards': ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Icy Prison'], 'images': ["https://api.scryfall.com/cards/named?format=image&version=normal&exact=Abdel%20Adrian%2C%20Gorion's%20Ward&face=front", 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Sakashima%20of%20a%20Thousand%20Faces&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Icy%20Prison&face=front'], 'results': ['Infinite blinking', 'Infinite creature tokens', 'Infinite ETB', 'Infinite LTB']}

# %%
combos_plus_one = flatten(combos_plus_one)

# %%
# remove unwanted cards from graph

removelist = [
    "Ashnod's Altar" ,
    'Defiler of Faith'
             , "Myr Battlesphere"
             , "Karmic Guide"
             , "Mycosynth Lattice"
             , "Sram's Expertise"
             , "Emry, Lurker of the Loch"
             , "Chromatic Orrery"
             , "Ornithopter"
             , "Encroaching Mycosynth"
             , "Palinchron"
             , "Glint Hawk"
             , "Whitemane Lion"
             , "Semblance Anvil"
             , "Deathrender"
             , "Altar of Dementia"
             , "Eldrazi Displacer"
             , "Myr Retriever"
             , "Phyrexian Walker"
             , "Phyrexian Altar"
             , "Dress Down"
             , "Mycosynth Golem"
             , "Memnite"
             , "Mind Over Matter"
             , "Dross Scorpion"
             , "Salvagin Station"
             , "Animation Module"
             , "Blasting Station"
             , "Nim Deathmantle"
             , "Altar of the Brood"
             , "Time Warp"
             , "Time Stretch"
             , "Walk the Aeons"
             , "Cloudstone Curio"
             , "Temporal Manipulation"
             , "Capture of Jingzhou"
             , "Sakashima of a Thousand Faces"
             , "Mysterious Limousine"
            ]

combo_to_be_removed = []

for combo in combos_plus_one:
    for b in removelist:
        if b in combo['cards']:
            print(combo['cards'])
            combo_to_be_removed.append(combo)

for c in combo_to_be_removed:
    if c in combos_plus_one:
        combos_plus_one.remove(c)
# Out:
# ["Abdel Adrian, Gorion's Ward", 'Eldrazi Displacer']
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', "Ashnod's Altar"]
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', "Ashnod's Altar"]
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Phyrexian Altar']
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Phyrexian Altar']
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Blasting Station']
# ["Abdel Adrian, Gorion's Ward", 'Karmic Guide', 'Blasting Station']
# ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', "Ashnod's Altar"]
# ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', "Ashnod's Altar"]
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Glasspool Mimic // Glasspool Shore']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Spark Double']
# ["Abdel Adrian, Gorion's Ward", 'Glorious Protector', 'Mysterious Limousine']
# ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', 'Phyrexian Altar']
# ["Abdel Adrian, Gorion's Ward", 'Nim Deathmantle', 'Phyrexian Altar']
# ["Abdel Adrian, Gorion's Ward", 'Mysterious Limousine', 'Oblivion Ring']
# ["Abdel Adrian, Gorion's Ward", 'Lumbering Battlement', 'Mysterious Limousine']
# ["Abdel Adrian, Gorion's Ward", 'Mysterious Limousine', 'Leonin Relic-Warder']
# ["Abdel Adrian, Gorion's Ward", 'Cloudstone Curio', 'Phyrexian Altar']
# ["Abdel Adrian, Gorion's Ward", 'Cloudstone Curio', 'Phyrexian Altar']
# ['Sakashima of a Thousand Faces', "Abdel Adrian, Gorion's Ward", 'Fiend Hunter']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Clever Impersonator']
# ["Abdel Adrian, Gorion's Ward", 'Phantom Steed', 'Mysterious Limousine']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Lumbering Battlement']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Oblivion Ring']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Phantom Steed']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Journey to Nowhere']
# ['Sakashima of a Thousand Faces', "Abdel Adrian, Gorion's Ward", 'Wormfang Drake']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Clone']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Mirror Image']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Suspension Field']
# ["Abdel Adrian, Gorion's Ward", 'Sakashima of a Thousand Faces', 'Icy Prison']

# %%
create_graph(combos_plus_one)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/AbdelAdrian,Gorion'sWard.png
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/RestorationAngel.png
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Ephemerate.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/FelidarGuardian.png
# Ephemerate.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# RestorationAngel.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Cloudshift.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# FelidarGuardian.png already downloaded
# Cloudshift.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# RestorationAngel.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/FiendHunter.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Archaeomancer.png
# Ephemerate.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Cloudshift.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/ArcaneSignet.png
# Archaeomancer.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# RestorationAngel.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/EssenceFlux.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# EssenceFlux.png already downloaded
# ArcaneSignet.png already downloaded
# Archaeomancer.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FelidarGuardian.png already downloaded
# EssenceFlux.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/DeadeyeNavigator.png
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Preston,theVanisher.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# Ephemerate.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/OblivionRing.png
# Preston,theVanisher.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# Cloudshift.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/TouchtheSpiritRealm.png
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/GloriousProtector.png
# TouchtheSpiritRealm.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# RestorationAngel.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/PegasusGuardian.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/JourneytoNowhere.png
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FelidarGuardian.png already downloaded
# PegasusGuardian.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# TouchtheSpiritRealm.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/LeoninRelic-Warder.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# GloriousProtector.png already downloaded
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/WispweaverAngel.png
# Cloudshift.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WispweaverAngel.png already downloaded
# Ephemerate.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Cloudshift.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Commander'sSphere.png
# Archaeomancer.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# OblivionRing.png already downloaded
# LeoninRelic-Warder.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# GloriousProtector.png already downloaded
# JourneytoNowhere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/LumberingBattlement.png
# TouchtheSpiritRealm.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# JourneytoNowhere.png already downloaded
# LeoninRelic-Warder.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# EssenceFlux.png already downloaded
# Commander'sSphere.png already downloaded
# Archaeomancer.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Preston,theVanisher.png already downloaded
# FiendHunter.png already downloaded
# EssenceFlux.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WispweaverAngel.png already downloaded
# PegasusGuardian.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/PhantomSteed.png
# GloriousProtector.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/SparkDouble.png
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/GlasspoolMimic.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# Archaeomancer.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/SplashPortal.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# GloriousProtector.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/DetentionSphere.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/SuspensionField.png
# OblivionRing.png already downloaded
# Preston,theVanisher.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# PegasusGuardian.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/ParallaxWave.png
# LeoninRelic-Warder.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# JourneytoNowhere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# GlasspoolMimic.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SuspensionField.png already downloaded
# LeoninRelic-Warder.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# GloriousProtector.png already downloaded
# SuspensionField.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# ParallaxWave.png already downloaded
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# LumberingBattlement.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# GloriousProtector.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/WormfangDrake.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# TouchtheSpiritRealm.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/CleverImpersonator.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# SparkDouble.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WispweaverAngel.png already downloaded
# EssenceFlux.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# WormfangDrake.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# WormfangDrake.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# GlasspoolMimic.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# SparkDouble.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# GlasspoolMimic.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# CleverImpersonator.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# JourneytoNowhere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# SuspensionField.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/MirrorImage.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# FiendHunter.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/Clone.png
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# DetentionSphere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# DetentionSphere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# MirrorImage.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# Clone.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# LumberingBattlement.png already downloaded
# CleverImpersonator.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# OblivionRing.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# MirrorImage.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# SparkDouble.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# Clone.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WormfangDrake.png already downloaded
# MirrorImage.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# Clone.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# JourneytoNowhere.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WormfangDrake.png already downloaded
# Clone.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# SuspensionField.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WormfangDrake.png already downloaded
# GlasspoolMimic.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WormfangDrake.png already downloaded
# SparkDouble.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# PhantomSteed.png already downloaded
# CleverImpersonator.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# MirrorImage.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# WormfangDrake.png already downloaded
# CleverImpersonator.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# SuspensionField.png already downloaded
# AbdelAdrian,Gorion'sWard.png already downloaded
# SparkDouble.png already downloaded
# Downloading Intruder Alarm to /home/michaelwagner/Documents/Projects/scryfall/card_img_cache/IcyPrison.png
# cards.html

# %%
all_cards = []
for combo in combos_plus_one:
    cards = combo['cards']
    all_cards.append(cards)

all_cards = set(flatten(all_cards))

for c in all_cards:
    print(c)
# Out:
# Fiend Hunter
# Glasspool Mimic // Glasspool Shore
# Clone
# Touch the Spirit Realm
# Detention Sphere
# Essence Flux
# Arcane Signet
# Cloudshift
# Glorious Protector
# Clever Impersonator
# Wormfang Drake
# Leonin Relic-Warder
# Preston, the Vanisher
# Felidar Guardian
# Pegasus Guardian // Rescue the Foal
# Mirror Image
# Parallax Wave
# Ephemerate
# Archaeomancer
# Wispweaver Angel
# Deadeye Navigator
# Oblivion Ring
# Splash Portal
# Abdel Adrian, Gorion's Ward
# Icy Prison
# Lumbering Battlement
# Phantom Steed
# Spark Double
# Commander's Sphere
# Journey to Nowhere
# Restoration Angel
# Suspension Field

# %%
images_mock = ['https://api.scryfall.com/cards/named?format=image&version=normal&exact=Xyris%2C%20the%20Writhing%20Storm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Intruder%20Alarm&face=front', 'https://api.scryfall.com/cards/named?format=image&version=normal&exact=Lore%20Broker&face=front']
image_url = images_mock[1]

# %%
# Out:
# IntruderAlarm.png already downloaded
# '/home/michaelwagner/Documents/Projects/scryfall/card_img_cache/IntruderAlarm.png'

# %%
# Out:
# /home/michaelwagner/Documents/Projects/scryfall
# /home/michaelwagner/Documents/Projects/scryfall/IntruderAlarm.png
